# %% [markdown]
# # 00 - Context
#
# **Power Grid Optimization — Notebook Series**
# Xinyu Li · Carnegie Mellon University
#
# ---

# %% [markdown]
# ## What is this series about?

# %% [markdown]
# ## Why power grid optimization?

# %% [markdown]
# ## Scope and organization

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ## Software and tools
